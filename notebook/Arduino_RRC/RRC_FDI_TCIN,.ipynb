# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt

from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler

from sklearn.ensemble import RandomForestClassifier

# %%
def readfile(bestand):
    table = None
    table = pd.read_excel(bestand, index_col=0)
    table['time'] = table.index
    
    X = table.select_dtypes(include='number')
    y = pd.get_dummies(table.select_dtypes(exclude='number') )
    y.drop(columns='Health_state_H', inplace=True)
    
    return X,y

# %%
def make_arr(XX):
    arr = pd.DataFrame(index=XX.index)
    arr[' ARR_1  '] = abs( (XX['V0_measured']-XX['V1_measured']) - (XX['V1_measured']-XX['V2_measured']) )
    
    dumV = XX['S'].diff().fillna(1).abs()*(XX['V0_measured']-XX['V2_measured'])
    dumV.replace(to_replace=0.0, value=np.nan, inplace=True)
    dumV.ffill(inplace=True)
    
    dumT = XX['S'].diff().fillna(1).abs()*(XX.index)             #identify all lines immediately after a switch transition
    dumT.replace(to_replace=0.0, inplace=True, method='ffill')   #forward the last switch time 

    arr[' ARR_2  '] = abs( (XX['V0_measured']-XX['V2_measured']) - dumV*np.exp(-(dumT.index - dumT)/4)  )
    
    return arr

# %%
# fit a RF model and determine gini importance

def selectRFmodel(XX,y):
#    imputer = KNNImputer(n_neighbors=3, weights="distance")
#    XX = imputer.fit_transform(XX)
    
    rfmodel = RandomForestClassifier(n_estimators = 100, criterion="gini",random_state = None)
    
    return rfmodel.fit(XX, y), rfmodel.feature_importances_

# %%
#load the balanced and complete training data in a pandas dataframe

#df_X, df_y = readfile("C:/Users/Admin/Pythonprojects/RAMS/data/Arduino_R10kR10kC200mu_10sec.xlsx")
df_X, df_y = readfile("https://raw.githubusercontent.com/chrisrijsdijk/RAMS/master/data/Arduino_R10kR10kC200mu_10sec.xlsx")

# %%
# infer RF models from df_X; df_y

X_names = df_X.columns      #load a string of column names to label the output of the random forest model afterwards...

rf_X_RC_model, rf_X_RC_featimp = selectRFmodel(df_X, df_y)

# %%
# infer RF models from arr's; df_y

df_as = make_arr(df_X)
as_names = df_as.columns      #load a string of column names to label the output of the random forest model afterwards...

rf_A_RC_model, rf_A_RC_featimp = selectRFmodel(df_as, df_y)

# %%
#rf_XA_RC_model.predict(df_Xas)
print('###########################################################################')
print(pd.DataFrame(rf_X_RC_featimp, index=X_names, columns=['Gini importance of the model X']).sort_values(by='Gini importance of the model X', ascending=False) )
print(' ')
print(pd.DataFrame(rf_A_RC_featimp, index=as_names, columns=['Gini importance of the model A']).sort_values(by='Gini importance of the model A', ascending=False) )
print('###########################################################################')
# Out:
# ###########################################################################
#              Gini importance of the model X
# V2_measured                        0.397304
# V1_measured                        0.369779
# time                               0.202113
# V0_measured                        0.022788
# S                                  0.008016
#
#           Gini importance of the model A
#  ARR_2                          0.521028
#  ARR_1                          0.478972
# ###########################################################################

# %%
val_X, val_y = readfile("C:/Users/Admin/Pythonprojects/RAMS/notebook/Arduino_RRC/kanweg.xlsx")

# %%
pd.concat([
    val_X,
    val_y,
    pd.DataFrame(rf_X_RC_model.predict(val_X), index=val_y.index)], axis='columns')
# Out:
#           S  V0_measured  V1_measured  V2_measured      time  Health_state_C  \
# 0.000000  1     4.995117     4.667969     4.326172  0.000000               0
# 1.025012  1     4.995117     4.746094     4.487305  1.025012               0
# 2.052483  1     4.995117     4.799805     4.604492  2.052483               0
# 3.078557  1     4.995117     4.848633     4.692383  3.078557               0
# 4.104397  1     4.995117     4.877930     4.760742  4.104397               0
# 5.127140  1     4.995117     4.907227     4.814453  5.127140               0
# 6.149997  1     4.995117     4.926758     4.853516  6.149997               0
# 7.169579  1     4.995117     4.936523     4.882812  7.169579               0
# 8.201067  1     4.995117     4.956055     4.912109  8.201067               0
# 9.226753  1     4.995117     4.960938     4.931641  9.226753               0
# 0.000000  0     0.000000     2.480469     4.946289  0.000000               0
# 1.026565  0     0.000000     1.928711     3.852539  1.026565               0
# 2.051419  0     0.000000     1.508789     3.017578  2.051419               0
# 3.071841  0     0.000000     1.176758     2.363281  3.071841               0
# 4.102139  0     0.000000     0.922852     1.850586  4.102139               0
# 5.121914  0     0.000000     0.727539     1.455078  5.121914               0
# 6.153328  0     0.000000     0.566406     1.142578  6.153328               0
# 7.173815  0     0.000000     0.449219     0.898438  7.173815               0
# 8.196474  0     0.000000     0.351562     0.708008  8.196474               0
# 9.221674  0     0.000000     0.278320     0.561523  9.221674               0
# 0.000000  1     4.990234     2.719727     0.449219  0.000000               1
# 1.022105  1     4.990234     3.227539     1.459961  1.022105               1
# 2.041703  1     4.995117     3.613281     2.241211  2.041703               1
# 3.063193  1     4.995117     3.916016     2.841797  3.063193               1
# 4.086257  1     4.995117     4.145508     3.305664  4.086257               1
# 5.123195  1     4.995117     4.335938     3.676758  5.123195               1
# 6.143205  1     4.995117     4.477539     3.955078  6.143205               1
# 7.174460  1     4.995117     4.589844     4.184570  7.174460               1
# 8.201540  1     4.995117     4.677734     4.360352  8.201540               1
# 9.232888  1     4.995117     4.746094     4.492188  9.232888               1
# 0.000000  0     0.000000     2.309570     4.599609  0.000000               1
# 1.029223  0     0.000000     1.791992     3.574219  1.029223               1
# 2.053084  0     0.000000     1.396484     2.797852  2.053084               1
# 3.079606  0     0.000000     1.088867     2.187500  3.079606               1
# 4.110636  0     0.000000     0.854492     1.708984  4.110636               1
# 5.131357  0     0.000000     0.668945     1.337891  5.131357               1
# 6.151294  0     0.000000     0.527344     1.054688  6.151294               1
# 7.180903  0     0.000000     0.410156     0.825195  7.180903               1
# 8.203539  0     0.000000     0.322266     0.649414  8.203539               1
# 9.223471  0     0.000000     0.253906     0.507812  9.223471               1
#
#           Health_state_R  0  1
# 0.000000               0  1  0
# 1.025012               0  1  0
# 2.052483               0  1  0
# 3.078557               0  1  0
# 4.104397               0  1  0
# 5.127140               0  1  0
# 6.149997               0  1  0
# 7.169579               0  1  0
# 8.201067               0  1  0
# 9.226753               0  1  0
# 0.000000               0  1  0
# 1.026565               0  0  0
# 2.051419               0  1  0
# 3.071841               0  0  0
# 4.102139               0  0  0
# 5.121914               0  0  0
# 6.153328               1  0  0
# 7.173815               1  0  0
# 8.196474               1  0  0
# 9.221674               1  0  0
# 0.000000               0  0  0
# 1.022105               0  0  0
# 2.041703               0  0  0
# 3.063193               0  0  0
# 4.086257               0  0  0
# 5.123195               0  0  0
# 6.143205               0  0  0
# 7.174460               0  0  0
# 8.201540               0  0  0
# 9.232888               0  0  0
# 0.000000               0  0  0
# 1.029223               0  0  0
# 2.053084               0  0  0
# 3.079606               0  0  0
# 4.110636               0  0  0
# 5.131357               0  0  0
# 6.151294               0  0  0
# 7.180903               0  0  0
# 8.203539               0  0  0
# 9.223471               0  0  0

# %%
val_as = make_arr(val_X)

# %%
pd.concat([
    val_as,
    val_y,
    pd.DataFrame(rf_A_RC_model.predict(val_as), index=val_y.index)], axis='columns')
# Out:
#            ARR_1     ARR_2    Health_state_C  Health_state_R  0  1
# 0.000000  0.014648  0.000000               0               0  1  0
# 1.025012  0.009766  0.009915               0               0  0  0
# 2.052483  0.000000  0.009822               0               0  0  0
# 3.078557  0.009766  0.007108               0               0  0  0
# 4.104397  0.000000  0.005377               0               0  0  0
# 5.127140  0.004883  0.004996               0               0  0  0
# 6.149997  0.004883  0.002167               0               0  1  0
# 7.169579  0.004883  0.000885               0               0  1  0
# 8.201067  0.004883  0.003086               0               0  1  0
# 9.226753  0.004883  0.003144               0               0  1  0
# 0.000000  0.014648  0.000000               0               0  1  0
# 1.026565  0.004883  0.025864               0               0  0  0
# 2.051419  0.000000  0.055820               0               0  0  0
# 3.071841  0.009766  0.068408               0               0  0  0
# 4.102139  0.004883  0.076824               0               0  0  0
# 5.121914  0.000000  0.080483               0               0  0  0
# 6.153328  0.009766  0.080417               0               1  0  0
# 7.173815  0.000000  0.075452               0               1  0  0
# 8.196474  0.004883  0.070686               0               1  0  0
# 9.221674  0.004883  0.068294               0               1  0  0
# 0.000000  0.000000  0.000000               1               0  0  0
# 1.022105  0.004883  0.013217               1               0  0  0
# 2.041703  0.009766  0.028207               1               0  0  0
# 3.063193  0.004883  0.041918               1               0  0  0
# 4.086257  0.009766  0.054545               1               0  0  0
# 5.123195  0.000000  0.056796               1               0  0  0
# 6.143205  0.004883  0.062435               1               0  0  0
# 7.174460  0.000000  0.055114               1               0  0  0
# 8.201540  0.000000  0.050404               1               0  0  0
# 9.232888  0.004883  0.051381               1               0  0  0
# 0.000000  0.019531  0.000000               1               0  0  0
# 1.029223  0.009766  0.018114               1               0  0  0
# 2.053084  0.004883  0.044826               1               0  0  0
# 3.079606  0.009766  0.057611               1               0  0  0
# 4.110636  0.000000  0.063043               1               0  0  0
# 5.131357  0.000000  0.062653               1               0  0  0
# 6.151294  0.000000  0.066470               1               0  0  0
# 7.180903  0.004883  0.061246               1               0  0  0
# 8.203539  0.004883  0.057807               1               0  0  0
# 9.223471  0.000000  0.049359               1               0  0  0
